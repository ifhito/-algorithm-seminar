# %%
# 1.1
# ハッシュ値を計算し、同じハッシュテーブルに割り当てられるものがあった場合
def myhash(s, size):
    s_len = ord(s)
    
    return s_len % size

def insert_to_list(string):
    size = '''文字コードの大きさ分'''
    sequence =[None for _ in range(size)]
    for s in string:
        my_hash = myhash(s, size)
        if sequence[my_hash]:
            return True
        sequence[my_hash] = s
    
    return False

sentence = 'adg'
if insert_to_list(sentence) == True:
    print('yes')
else:
    print('no')

# 新しいデータ構造が用意できない場合
# Out:
# no

# %%
#1.1正解

# O(N)
import unittest


def unique(string):
    # Assuming character set is ASCII (128 characters)
    if len(string) > 128:
        return False

    char_set = [False for _ in range(128)]
    for char in string:
        val = ord(char)
        if char_set[val]:
            # Char already found in string
            return False
        char_set[val] = True

    return True


class Test(unittest.TestCase):
    dataT = [('abcd'), ('s4fad'), ('')]
    dataF = [('23ds2'), ('hb 627jh=j ()')]

    def test_unique(self):
        # true check
        for test_string in self.dataT:
            actual = unique(test_string)
            self.assertTrue(actual)
        # false check
        for test_string in self.dataF:
            actual = unique(test_string)
            self.assertFalse(actual)

if __name__ == "__main__":
    unittest.main()

# %%
# 1.2
'''文字コードの番号に文字列を直してしまい、合計をとった。合計の数が同じな時、全ての文字が共通していると言えるのでTrueとした'''
'''128個の素数'''
def isPrime(size):
    prime_list = []
    n = 2
    while True:
        
        if len(prime_list) >= size:
            break
        if n == 2:
            prime_list.append(n)
            n+= 1
            continue
        p = 0
        while True:
            if p >= len(prime_list):
                prime_list.append(n)
                break
            if n % prime_list[p] == 0:
                break
            p += 1
        n += 1
    return prime_list
                
            
def Comp(first, second):
    first_count = 1
    second_count = 1
    prime_list = isPrime(128)
    for f in first:
        first_count *= prime_list[ord(f)]
    
    for s in second:
        second_count *= prime_list[ord(s)]
    
    if first_count == second_count:
        return True
    else:
        return False
    
Comp('auemikk','akkuemi')
# Out:
# True

# %%
dataT = (
    ('abcd', 'bacd'),
    ('3563476', '7334566'),
    ('wef34f', 'wffe34'),
)
dataF = (
    ('abcd', 'd2cba'),
    ('2354', '1234'),
    ('dcw4f', 'dcw5f'),
)

for dT in dataT:
    print(Comp(dT[0], dT[1]))
for dF in dataF:
    print(Comp(dF[0], dF[1]))
# Out:
# True
# True
# True
# False
# False
# False

# %%
#1.2 正解
# O(N)
import unittest
from collections import Counter


def check_permutation(str1, str2):
    if len(str1) != len(str2):
        return False
    counter = Counter()
    for c in str1:
        counter[c] += 1
    for c in str2:
        if counter[c] == 0:
            return False
        counter[c] -= 1
    return True


class Test(unittest.TestCase):
    dataT = (
        ('abcd', 'bacd'),
        ('3563476', '7334566'),
        ('wef34f', 'wffe34'),
    )
    dataF = (
        ('abcd', 'd2cba'),
        ('2354', '1234'),
        ('dcw4f', 'dcw5f'),
    )

    def test_cp(self):
        # true check
        for test_strings in self.dataT:
            result = check_permutation(*test_strings)
            self.assertTrue(result)
        # false check
        for test_strings in self.dataF:
            result = check_permutation(*test_strings)
            self.assertFalse(result)


if __name__ == "__main__":
    unittest.main()
# Out:
# E
# ...
# ERROR: /Users/a (unittest.loader._FailedTest)
# ----------------------------------------------------------------------
# AttributeError: module '__main__' has no attribute '/Users/a'
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.005s
#
# FAILED (errors=1)
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: True
# /Users/a.seki/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3334: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# 1.3
'''空白があったら置き換えてnumをその分プラスしていった'''
def Replace(word):
    num = 0
    word_split = []
    while True:
        if num == len(word):
            break
        if word[num] == ' ':
            word = word[:num] + '%20' + word[num+1:]
            print(id(word))
            num += 3
        else:
            num += 1
    
    return word

Replace('I have a pen ')
# Out:
# 4532454448
# 4521646560
# 4525888016
# 4521646560
# 'I%20have%20a%20pen%20'

# %%
# O(N)
import unittest


def urlify(string, length):
    '''function replaces single spaces with %20 and removes trailing spaces'''
    new_index = len(string)

    for i in reversed(range(length)):
        if string[i] == ' ':
            # Replace spaces
            string[new_index - 3:new_index] = '%20'
            new_index -= 3
        else:
            # Move characters
            string[new_index - 1] = string[i]
            new_index -= 1

    return string


class Test(unittest.TestCase):
    '''Test Cases'''
    # Using lists because Python strings are immutable
    data = [
        (list('much ado about nothing      '), 22,
         list('much%20ado%20about%20nothing')),
        (list('Mr John Smith    '), 13, list('Mr%20John%20Smith'))]

    def test_urlify(self):
        for [test_string, length, expected] in self.data:
            actual = urlify(test_string, length)
            self.assertEqual(actual, expected)

if __name__ == "__main__":
    unittest.main()

# %%
# 1.4

# 方法は配列列を128のように長さ分持って、ハッシュ値で1,0,1と交互に変更していく。
# もしも偶数会の場合は0,奇数回の場合は1になるのでそれぞれの項が交互に変わっていく。
# 最後に項全体の合計をとって文字列の長さが奇数の場合は1, 偶数の場合は0の時回文が成立するとした
def Palindrome(string):
    binaly_str = []
    count = 0
    length = len(string)
    num1 = 0
    num2 = 0
    num3 = 0
    size = 128
    string = string.lower()
    string = string.replace(' ', '')
    while True:
        if num1 >= size:
            break
        binaly_str.append(0)
        num1 += 1

    while True:
        if num2 >= len(string):
            break
        my_hash = ord(string[num2])
        if binaly_str[my_hash] == 0:
            binaly_str[my_hash] = 1
        else:
            binaly_str[my_hash] = 0
        num2 += 1
    while True:
        if num3 >= len(binaly_str):
            break
        count += binaly_str[num3]
        num3 += 1
        
    if count < 2:
        return True
    else:
        return False
        
Palindrome('Tact Coa')
# Out:
# True

# %%
data = [
    ('Tact Coa', True),
    ('jhsabckuj ahjsbckj', True),
    ('Able was I ere I saw Elba', True),
    ('So patient a nurse to nurse a patient so', False),
    ('Random Words', False),
    ('Not a Palindrome', False),
    ('no x in nixon', True),
    ('azAZ', True)]

for d0, d1  in data:
    print(Palindrome(d0) == d1)
# Out:
# True
# True
# True
# True
# True
# True
# True
# True

# %%
# O(N)
import unittest


def pal_perm(phrase):
    '''function checks if a string is a permutation of a palindrome or not'''
    table = [0 for _ in range(ord('z') - ord('a') + 1)]
    countodd = 0
    for c in phrase:
        x = char_number(c)
        if x != -1:
            table[x] += 1
            if table[x] % 2:
                countodd += 1
            else:
                countodd -= 1

    return countodd <= 1

def char_number(c):
    a = ord('a')
    z = ord('z')
    A = ord('A')
    Z = ord('Z')
    val = ord(c)

    if a <= val <= z:
        return val - a
    elif A <= val <= Z:
        return val - A
    return -1


class Test(unittest.TestCase):
    '''Test Cases'''
    data = [
        ('Tact Coa', True),
        ('jhsabckuj ahjsbckj', True),
        ('Able was I ere I saw Elba', True),
        ('So patient a nurse to nurse a patient so', False),
        ('Random Words', False),
        ('Not a Palindrome', False),
        ('no x in nixon', True),
        ('azAZ', True)]

    def test_pal_perm(self):
        for [test_string, expected] in self.data:
            actual = pal_perm(test_string)
            self.assertEqual(actual, expected)

if __name__ == "__main__":
    unittest.main()

# %%
# 1.5
# 文字列の長さが等しい場合はフラグを立てておく。等しくない場合は共通の文字になるまで片方を動かし、共通の時に両方動かす。
# 等しい場合はそれぞれの文字を動かしていく。全体として長い方の文字列-1だけ共通していれば、Trueを返すようにした。
def Same(word1, word2):
    flag = False
    num1 = 0
    num2 = 0
    true_count = 0
    if word1 == word2:
        return True
    if len(word1) < len(word2):
        word1, word2 = word2, word1
    if len(word1) == len(word2):
        flag = True
    
    while True:
        if num2 == len(word2) or num1 == len(word1):
            break
        if word1[num1] == word2[num2]:
            num1 += 1
            num2 += 1
            true_count += 1
        elif word1[num1] != word2[num2] and flag == True:
            num1 += 1
            num2 += 1
        elif word1[num1] != word2[num2] and flag == False:
            num1 += 1
    if true_count == len(word1) - 1:
        return True
    else:
        return False

Same('pale', 'ple')
# Out:
# True

# %%
data = [
    ('pale', 'ple', True),
    ('pales', 'pale', True),
    ('pale', 'bale', True),
    ('paleabc', 'pleabc', True),
    ('pale', 'ble', False),
    ('a', 'b', True),
    ('', 'd', True),
    ('d', 'de', True),
    ('pale', 'pale', True),
    ('pale', 'ple', True),
    ('ple', 'pale', True),
    ('pale', 'bale', True),
    ('pale', 'bake', False),
    ('pale', 'pse', False),
    ('ples', 'pales', True),
    ('pale', 'pas', False),
    ('pas', 'pale', False),
    ('pale', 'pkle', True),
    ('pkle', 'pable', False),
    ('pal', 'palks', False),
    ('palks', 'pal', False)
]

for d0, d1, d2 in data:
    print(Same(d0, d1) == d2)
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True

# %%
class Test(unittest.TestCase):
    '''Test Cases'''


    def test_one_away(self):
        for [test_s1, test_s2, expected] in self.data:
            actual = (test_s1, test_s2)
            self.assertEqual(actual, expected)

if __name__ == "__main__":
    unittest.main()

# %%
# O(N)
import unittest


def one_away(s1, s2):
    '''Check if a string can converted to another string with a single edit'''
    if len(s1) == len(s2):
        return one_edit_replace(s1, s2)
    elif len(s1) + 1 == len(s2):
        return one_edit_insert(s1, s2)
    elif len(s1) - 1 == len(s2):
        return one_edit_insert(s2, s1)
    return False


def one_edit_replace(s1, s2):
    edited = False
    for c1, c2 in zip(s1, s2):
        if c1 != c2:
            if edited:
                return False
            edited = True
    return True


def one_edit_insert(s1, s2):
    edited = False
    i, j = 0, 0
    while i < len(s1) and j < len(s2):
        if s1[i] != s2[j]:
            if edited:
                return False
            edited = True
            j += 1
        else:
            i += 1
            j += 1
    return True


class Test(unittest.TestCase):
    '''Test Cases'''
    data = [
        ('pale', 'ple', True),
        ('pales', 'pale', True),
        ('pale', 'bale', True),
        ('paleabc', 'pleabc', True),
        ('pale', 'ble', False),
        ('a', 'b', True),
        ('', 'd', True),
        ('d', 'de', True),
        ('pale', 'pale', True),
        ('pale', 'ple', True),
        ('ple', 'pale', True),
        ('pale', 'bale', True),
        ('pale', 'bake', False),
        ('pale', 'pse', False),
        ('ples', 'pales', True),
        ('pale', 'pas', False),
        ('pas', 'pale', False),
        ('pale', 'pkle', True),
        ('pkle', 'pable', False),
        ('pal', 'palks', False),
        ('palks', 'pal', False)
    ]

    def test_one_away(self):
        for [test_s1, test_s2, expected] in self.data:
            actual = Same(test_s1, test_s2)
            self.assertEqual(actual, expected)

if __name__ == "__main__":
    unittest.main()
# Out:
# E
# ...
# ERROR: /Users/a (unittest.loader._FailedTest)
# ----------------------------------------------------------------------
# AttributeError: module '__main__' has no attribute '/Users/a'
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.020s
#
# FAILED (errors=1)
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: True
# /Users/a.seki/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3334: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
